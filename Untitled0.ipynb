# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path="/content/drive/MyDrive/datasheet/train_updated.csv"
data=pd.read_csv(path)

# %%
x = np.array(data['x'])
y = np.array(data['y'])
m = x.size

n = y.size
m,n
# Out:
# (699, 699)

# %%
x.shape
# Out:
# (699,)

# %%
w = 0
b=0
itr = 10000
alpha = 0.000001
cost_history= []
w_history =[]
b_history = []

# %%
i = 0
while (i<=itr):
    yp = w*x+b
    cost = (1/(2*m))*np.sum(np.square(yp - y))
    djw = (1/m)*np.dot(x.T,yp-y)
    djb = (1/m)*(yp-y)
    w = w - alpha*djw
    b = b - alpha*djb
    cost_history.append(cost)
    w_history.append(w)
    b_history.append(b)
    i=i+1
    if(i%(itr//10) == 0):
      print("Cost is :", cost)
# Out:
# Cost is : 6.024077959513101
# Cost is : 3.9378976003158086
# Cost is : 3.935288411192824
# Cost is : 3.9352739162216146
# Cost is : 3.9352626524837766
# Cost is : 3.9352513928020048
# Cost is : 3.935240133157461
# Cost is : 3.9352288735451415
# Cost is : 3.9352176139650368
# Cost is : 3.935206354417148

# %%
rng = np.arange(0, i) # expressing values of'iter' (equally spaced ) on the X axis
plt.plot(rng, cost_history)# clist on y axis
plt.show()

# %%
path="/content/drive/MyDrive/datasheet/test.csv"
test_dataset=pd.read_csv(path)

# %%
test_dataset
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
x_test=np.array(test_dataset['x'])
y_test=np.array(test_dataset['y'])
r=x_test.size
r
# Out:
# 300

# %%
w_final = w_history[-1]
b_final = b_history[-1][-1]
ypf = w_final*x_test + b_final
#er=((y_test-ypf)/y_test)*100
#ac = 100 - er
#ac
sq = np.sum(np.square(y_test - ypf))
rt= sqrt(sq/r)
rt
# Out:
# 3.0747161334550412
